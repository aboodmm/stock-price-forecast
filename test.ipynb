# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np
import math

mydict = {
            'name' : ['Abdul', 'John', 'Ali', 'rob', 'Mohamed'],
            'salary' : [1985000, 50000, 75000, 400000, 90000]
        }
data = pandas.DataFrame(mydict)
data
# Out:
#       name   salary
# 0    Abdul  1985000
# 1     John    50000
# 2      Ali    75000
# 3      rob   400000
# 4  Mohamed    90000

# %%
# %%time
a = [1,2,3,4,5]

x = [1, 2, 3, 4]
y = [8, 4, 3, 1]

plt.plot(a, marker='o')

plt.plot(x, y, marker='o')
# Out:
# CPU times: user 15.8 ms, sys: 1.73 ms, total: 17.5 ms
# Wall time: 16.1 ms

# %%
c = np.array([1, 2.0, 3])
print(c)
# Out:
# [1. 2. 3.]

# %% [markdown]
# As you can see there is some code here that I have written.
# ### Markdown

# %%
sinelist = [math.sin(0.5*i*math.pi) for i in range(10)]
plt.plot(sinelist)

# %%
basedata = [
    [1, 2, 3, 4, 5],
    [9.0,3.8,40.123,6.91,5],
    [925.2,123.0,1234,56,61],
    [9,8,7,8,4]
]
testdf = pandas.DataFrame(basedata, columns=['a','b','c','d','e'])

testdf['b'] = testdf['b'].astype(int)

testdf
# Out:
#        a    b         c      d   e
# 0    1.0    2     3.000   4.00   5
# 1    9.0    3    40.123   6.91   5
# 2  925.2  123  1234.000  56.00  61
# 3    9.0    8     7.000   8.00   4
